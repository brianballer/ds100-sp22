# %% [markdown]
# # Pandas Basics
#
# A high-level overview of the [Pandas](https://pandas.pydata.org) library. This is not a standalone notebook. Please see the slides or video for a narrative explanation of what is going on.
#
# Alternately, lab 2 provides a narrative explanation of much of the content of this notebook.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from IPython import display

plt.style.use('fivethirtyeight')
sns.set_context("notebook")

# %%
bill = np.array([1,2,2,2,4])
plt.hist(bill)
# Out:
# (array([1., 0., 0., 3., 0., 0., 0., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Reading in DataFrames from Files

# %% [markdown]
# Pandas has a number of very useful file reading tools. You can see them enumerated by typing "pd.re" and pressing tab. We'll be using read_csv today.

# %%
# !ls
# Out:
# sample_data

# %%
url = "https://raw.githubusercontent.com/archenclan/dsKal100/main/lec/lec03/elections.csv"

elections = pd.read_csv(url)
elections["Candidate"] # if we end a cell with an expression or variable name, the result will print
# Out:
# 0         Andrew Jackson
# 1      John Quincy Adams
# 2         Andrew Jackson
# 3      John Quincy Adams
# 4         Andrew Jackson
#              ...
# 177           Jill Stein
# 178         Joseph Biden
# 179         Donald Trump
# 180         Jo Jorgensen
# 181       Howard Hawkins
# Name: Candidate, Length: 182, dtype: object

# %%
# from google.colab import data_table
# data_table.enable_dataframe_formatter()

# %%
# from google.colab import data_table
# from vega_datasets import data

# data_table.enable_dataframe_formatter()
#data_table.disable_dataframe_formatter()

# data.airports()

# %%
elections.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
print(elections)
#plt.hist(np.array([1,2,3,4]))
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
plt.hist(elections["Year"])
# Out:
# (array([12., 15., 11., 19., 23., 17., 16., 19., 24., 26.]),
#  array([1824. , 1843.6, 1863.2, 1882.8, 1902.4, 1922. , 1941.6, 1961.2,
#         1980.8, 2000.4, 2020. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# As a simple indexing example, consider the code below, which returns the first 5 rows of the DataFrame.

# %%
elections.loc[0:4]  ## loc is inclusive of end of slice, vice exclusive; 0:4 gives [0,1,2,3,4]
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %% [markdown]
# We can also use the head command to return only a few rows of a dataframe.

# %%
elections.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
## sets the index to Year, but doesn't alter the df??  Need to save it off to another df

bill = elections.set_index("Year")

elections.set_index("Year").head()
# Out:
#               Candidate                  Party  Popular vote Result          %
# Year
# 1824     Andrew Jackson  Democratic-Republican        151271   loss  57.210122
# 1824  John Quincy Adams  Democratic-Republican        113142    win  42.789878
# 1828     Andrew Jackson             Democratic        642806    win  56.203927
# 1828  John Quincy Adams    National Republican        500897   loss  43.796073
# 1832     Andrew Jackson             Democratic        702735    win  54.574789

# %% [markdown]
# Or the tail command to get the last so many rows.

# %%
elections.tail(5)
# Out:
#      Year       Candidate        Party  Popular vote Result          %
# 177  2016      Jill Stein        Green       1457226   loss   1.073699
# 178  2020    Joseph Biden   Democratic      81268924    win  51.311515
# 179  2020    Donald Trump   Republican      74216154   loss  46.858542
# 180  2020    Jo Jorgensen  Libertarian       1865724   loss   1.177979
# 181  2020  Howard Hawkins        Green        405035   loss   0.255731

# %%
bill.tail(5)
# Out:
#            Candidate        Party  Popular vote Result          %
# Year
# 2016      Jill Stein        Green       1457226   loss   1.073699
# 2020    Joseph Biden   Democratic      81268924    win  51.311515
# 2020    Donald Trump   Republican      74216154   loss  46.858542
# 2020    Jo Jorgensen  Libertarian       1865724   loss   1.177979
# 2020  Howard Hawkins        Green        405035   loss   0.255731

# %%
## is bill aliased with elections??

bill.loc[2020,"Candidate"]
# Out:
# Year
# 2020      Joseph Biden
# 2020      Donald Trump
# 2020      Jo Jorgensen
# 2020    Howard Hawkins
# Name: Candidate, dtype: object

# %%
## when using loc with bill, the index is different and we must use the new index
bill.loc[2020,"Candidate"] = "Homer Simpson"

bill.tail(8)
# Out:
#             Candidate        Party  Popular vote Result          %
# Year
# 2016    Evan McMullin  Independent        732273   loss   0.539546
# 2016     Gary Johnson  Libertarian       4489235   loss   3.307714
# 2016  Hillary Clinton   Democratic      65853514   loss  48.521539
# 2016       Jill Stein        Green       1457226   loss   1.073699
# 2020    Homer Simpson   Democratic      81268924    win  51.311515
# 2020    Homer Simpson   Republican      74216154   loss  46.858542
# 2020    Homer Simpson  Libertarian       1865724   loss   1.177979
# 2020    Homer Simpson        Green        405035   loss   0.255731

# %%
elections.tail(8)

# changes to bill don't change elections
# Out:
#      Year        Candidate        Party  Popular vote Result          %
# 174  2016    Evan McMullin  Independent        732273   loss   0.539546
# 175  2016     Gary Johnson  Libertarian       4489235   loss   3.307714
# 176  2016  Hillary Clinton   Democratic      65853514   loss  48.521539
# 177  2016       Jill Stein        Green       1457226   loss   1.073699
# 178  2020     Joseph Biden   Democratic      81268924    win  51.311515
# 179  2020     Donald Trump   Republican      74216154   loss  46.858542
# 180  2020     Jo Jorgensen  Libertarian       1865724   loss   1.177979
# 181  2020   Howard Hawkins        Green        405035   loss   0.255731

# %% [markdown]
# If we want a subset of the columns, we can also use loc just to ask for those.

# %%
elections.loc[0:2, "Year":"Party"]
# Out:
#    Year          Candidate                  Party
# 0  1824     Andrew Jackson  Democratic-Republican
# 1  1824  John Quincy Adams  Democratic-Republican
# 2  1828     Andrew Jackson             Democratic

# %%
elections["Year"]
# Out:
# 0      1824
# 1      1824
# 2      1828
# 3      1828
# 4      1832
#        ...
# 177    2016
# 178    2020
# 179    2020
# 180    2020
# 181    2020
# Name: Year, Length: 182, dtype: int64

# %% [markdown]
# ### loc

# %% [markdown]
# loc selects items by row and column label.

# %%
elections.loc[[87, 25, 179], ["Year", "Candidate", "Result"]]
# Out:
#      Year             Candidate Result
# 87   1932        Herbert Hoover   loss
# 25   1860  John C. Breckinridge   loss
# 179  2020          Donald Trump   loss

# %%
elections.loc[[87, 25, 179], "Popular vote":"%"]
# Out:
#      Popular vote Result          %
# 87       15761254   loss  39.830594
# 25         848019   loss  18.138998
# 179      74216154   loss  46.858542

# %%
elections.loc[[87, 25, 179], "Popular vote"]
## returns a Series vice DF
# Out:
# 87     15761254
# 25       848019
# 179    74216154
# Name: Popular vote, dtype: int64

# %%
elections.loc[:, ["Year", "Candidate", "Result"]]
# Out:
#      Year          Candidate Result
# 0    1824     Andrew Jackson   loss
# 1    1824  John Quincy Adams    win
# 2    1828     Andrew Jackson    win
# 3    1828  John Quincy Adams   loss
# 4    1832     Andrew Jackson    win
# ..    ...                ...    ...
# 177  2016         Jill Stein   loss
# 178  2020       Joseph Biden    win
# 179  2020       Donald Trump   loss
# 180  2020       Jo Jorgensen   loss
# 181  2020     Howard Hawkins   loss
#
# [182 rows x 3 columns]

# %% [markdown]
# ### iloc

# %% [markdown]
# iloc selects items by row and column number.

# %%
elections.iloc[[1, 2, 3], [0, 1, 2]]
# Out:
#    Year          Candidate                  Party
# 1  1824  John Quincy Adams  Democratic-Republican
# 2  1828     Andrew Jackson             Democratic
# 3  1828  John Quincy Adams    National Republican

# %%
bill.iloc[-1, 0]
# Out:
# 'Homer Simpson'

# %%
elections.iloc[[1, 2, 3], 0:2]  ##iloc slices are NOT inclusive!
# Out:
#    Year          Candidate
# 1  1824  John Quincy Adams
# 2  1828     Andrew Jackson
# 3  1828  John Quincy Adams

# %%
elections.iloc[[1, 2, 3], 1]
# Out:
# 1    John Quincy Adams
# 2       Andrew Jackson
# 3    John Quincy Adams
# Name: Candidate, dtype: object

# %%
elections.iloc[:, [0, 1, 4]]
# Out:
#      Year          Candidate Result
# 0    1824     Andrew Jackson   loss
# 1    1824  John Quincy Adams    win
# 2    1828     Andrew Jackson    win
# 3    1828  John Quincy Adams   loss
# 4    1832     Andrew Jackson    win
# ..    ...                ...    ...
# 177  2016         Jill Stein   loss
# 178  2020       Joseph Biden    win
# 179  2020       Donald Trump   loss
# 180  2020       Jo Jorgensen   loss
# 181  2020     Howard Hawkins   loss
#
# [182 rows x 3 columns]

# %% [markdown]
# ### []

# %% [markdown]
# We could technically do anything we want using `loc` or `iloc`. However, in practice, the `[]` operator is often used instead to yield more concise code.
#
# `[]` is a bit trickier to understand than `loc` or `iloc`, but it does essentially the same thing.

# %% [markdown]
# If we provide a slice of row numbers, we get the numbered rows.

# %%
elections[3:7]   #[] "Kool-Aid" slices are NOT inclusive
# Out:
#    Year          Candidate                Party  Popular vote Result  \
# 3  1828  John Quincy Adams  National Republican        500897   loss
# 4  1832     Andrew Jackson           Democratic        702735    win
# 5  1832         Henry Clay  National Republican        484205   loss
# 6  1832       William Wirt         Anti-Masonic        100715   loss
#
#            %
# 3  43.796073
# 4  54.574789
# 5  37.603628
# 6   7.821583

# %% [markdown]
# If we provide a list of column names, we get the listed columns.

# %%
elections[["Year", "Candidate", "Result"]].tail(5)
# Out:
#      Year       Candidate Result
# 177  2016      Jill Stein   loss
# 178  2020    Joseph Biden    win
# 179  2020    Donald Trump   loss
# 180  2020    Jo Jorgensen   loss
# 181  2020  Howard Hawkins   loss

# %% [markdown]
# And if we provide a single column name we get back just that column.

# %%
elections["Candidate"].tail(5)
# Out:
# 177        Jill Stein
# 178      Joseph Biden
# 179      Donald Trump
# 180      Jo Jorgensen
# 181    Howard Hawkins
# Name: Candidate, dtype: object

# %%
weird = pd.DataFrame({
    1:["topdog","botdog"], 
    "1":["topcat","botcat"]
})
weird
# Out:
#         1       1
# 0  topdog  topcat
# 1  botdog  botcat

# %%
#weird[1] #try to predict the output  -- returns column 1 (the integer)
weird[1]
# Out:
# 0    topdog
# 1    botdog
# Name: 1, dtype: object

# %%
#weird["1"] #try to predict the output  -- returns column "1"
weird["1"]
# Out:
# 0    topcat
# 1    botcat
# Name: 1, dtype: object

# %%
#weird[1:] #try to predict the output -- returns row 1
weird[1:]
# Out:
#         1       1
# 1  botdog  botcat

# %% [markdown]
# ## Pandas Datastructures: DataFrames, Series, and Indices

# %%
type(elections)
# Out:
# pandas.core.frame.DataFrame

# %%
type(elections["Candidate"])
# Out:
# pandas.core.series.Series

# %%
#providing the column as a list will force a DF vices a Series
type(elections[["Candidate"]])
# Out:
# pandas.core.frame.DataFrame

# %%
mottos_url = "https://raw.githubusercontent.com/archenclan/dsKal100/main/lec/lec03/mottos.csv"
mottos = pd.read_csv(mottos_url, index_col = "State") ## note that he brings in the State as the index...not sure why
mottos.loc["Alabama":"California"]  # note that loc IS INCLUSIVE; uses row labels!
# Out:
#                                     Motto                 Translation  \
# State
# Alabama     Audemus jura nostra defendere  We dare defend our rights!
# Alaska                North to the future                           —
# Arizona                        Ditat Deus                God enriches
# Arkansas                   Regnat populus             The people rule
# California                Eureka (Εὕρηκα)             I have found it
#
#            Language Date Adopted
# State
# Alabama       Latin         1923
# Alaska      English         1967
# Arizona       Latin         1863
# Arkansas      Latin         1907
# California    Greek         1849

# %%
elections["Candidate"].tail(5).to_frame()

## .to_frame() will also force at DF
# Out:
#           Candidate
# 177      Jill Stein
# 178    Joseph Biden
# 179    Donald Trump
# 180    Jo Jorgensen
# 181  Howard Hawkins

# %%
type(elections["Candidate"].to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
elections[["Candidate"]].tail(5)
# Out:
#           Candidate
# 177      Jill Stein
# 178    Joseph Biden
# 179    Donald Trump
# 180    Jo Jorgensen
# 181  Howard Hawkins

# %%
mottos.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State')

# %%
elections.index
# Out:
# RangeIndex(start=0, stop=182, step=1)

# %%
mottos.columns  #what's the difference between "Index" and "array"??
# Out:
# Index(['Motto', 'Translation', 'Language', 'Date Adopted'], dtype='object')

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
elections.columns
# Out:
# Index(['Year', 'Candidate', 'Party', 'Popular vote', 'Result', '%'], dtype='object')

# %% [markdown]
# ## Conditional Selection

# %%
elections[elections["Party"] == "Independent"]
# Out:
#      Year         Candidate        Party  Popular vote Result          %
# 121  1976   Eugene McCarthy  Independent        740460   loss   0.911649
# 130  1980  John B. Anderson  Independent       5719850   loss   6.631143
# 143  1992        Ross Perot  Independent      19743821   loss  18.956298
# 161  2004       Ralph Nader  Independent        465151   loss   0.380663
# 167  2008       Ralph Nader  Independent        739034   loss   0.563842
# 174  2016     Evan McMullin  Independent        732273   loss   0.539546

# %%
elections["Party"] == "Independent"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# Name: Party, Length: 182, dtype: bool

# %% [markdown]
# Boolean array selection also works with `loc`!

# %%
elections.loc[elections["Party"] == "Independent"]
# Out:
#      Year         Candidate        Party  Popular vote Result          %
# 121  1976   Eugene McCarthy  Independent        740460   loss   0.911649
# 130  1980  John B. Anderson  Independent       5719850   loss   6.631143
# 143  1992        Ross Perot  Independent      19743821   loss  18.956298
# 161  2004       Ralph Nader  Independent        465151   loss   0.380663
# 167  2008       Ralph Nader  Independent        739034   loss   0.563842
# 174  2016     Evan McMullin  Independent        732273   loss   0.539546

# %%
elections[(elections["Result"] == "win") & (elections["%"] < 47)] # he uses parenthesis around each condition, it's a must
#elections[elections["Result"] == "win" & elections["%"] < 47]
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 20   1856     James Buchanan             Democratic       1835140    win
# 23   1860    Abraham Lincoln             Republican       1855993    win
# 47   1892   Grover Cleveland             Democratic       5553898    win
# 70   1912     Woodrow Wilson             Democratic       6296284    win
# 117  1968      Richard Nixon             Republican      31783783    win
# 140  1992       Bill Clinton             Democratic      44909806    win
# 173  2016       Donald Trump             Republican      62984828    win
#
#              %
# 1    42.789878
# 20   45.306080
# 23   39.699408
# 47   46.121393
# 70   41.933422
# 117  43.565246
# 140  43.118485
# 173  46.407862

# %%
#elections[[1]*len(elections)] #not sure what this is for??

# %%
# elections2 = pd.read_csv("annoying_puzzle2.csv")
# elections2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-2c6deeb51f17> in <module>
# ----> 1 elections2 = pd.read_csv("annoying_puzzle2.csv")
#       2 elections2
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#Which of the following yield the desired answer on the slides?
#elections2.iloc[[0, 3, 5], [0, 3]]
#elections2.loc[[0, 3, 5], "Candidate":"Year"]
elections2.loc[elections["%"] > 50]#, ["Candidate", "Year"]].head(3)
#elections2.loc[elections["%"] > 50, ["Candidate", "Year"]].iloc[0:2, :]
# Out:
#   Candidate        Party          %  Year Result
# 0    Reagan   Republican  50.897944  1980    win
# 2  Anderson  Independent   6.631143  1980   loss
# 4   Mondale   Democratic  40.729429  1984   loss

# %%
elections2 = elections[(elections["Year"] == 1980) | (elections["Year"] == 1984) | (elections["Year"] == 1988)]
elections2
# Out:
#      Year          Candidate         Party  Popular vote Result          %
# 127  1980     Barry Commoner      Citizens        233052   loss   0.270182
# 128  1980           Ed Clark   Libertarian        921128   loss   1.067883
# 129  1980       Jimmy Carter    Democratic      35480115   loss  41.132848
# 130  1980   John B. Anderson   Independent       5719850   loss   6.631143
# 131  1980      Ronald Reagan    Republican      43903230    win  50.897944
# 132  1984     David Bergland   Libertarian        228111   loss   0.247245
# 133  1984      Ronald Reagan    Republican      54455472    win  59.023326
# 134  1984     Walter Mondale    Democratic      37577352   loss  40.729429
# 135  1988  George H. W. Bush    Republican      48886597    win  53.518845
# 136  1988      Lenora Fulani  New Alliance        217221   loss   0.237804
# 137  1988    Michael Dukakis    Democratic      41809074   loss  45.770691
# ...

# %%
#filter for all the candidates in parties that start with "A" (there are 4 of them)

(
    elections[(elections["Party"] == "Anti-Masonic")  | 
              (elections["Party"] == "American")      |
              (elections["Party"] == "Anti-Monopoly") |
              (elections["Party"] == "American Independent")]
)
#Note: The parentheses surrounding the code make it possible to break the code on to multiple lines for readability
# Out:
#      Year           Candidate                 Party  Popular vote Result  \
# 6    1832        William Wirt          Anti-Masonic        100715   loss
# 22   1856    Millard Fillmore              American        873053   loss
# 38   1884     Benjamin Butler         Anti-Monopoly        134294   loss
# 115  1968      George Wallace  American Independent       9901118   loss
# 119  1972     John G. Schmitz  American Independent       1100868   loss
# 124  1976       Lester Maddox  American Independent        170274   loss
# 126  1976  Thomas J. Anderson              American        158271   loss
#
#              %
# 6     7.821583
# 22   21.554001
# 38    1.335838
# 115  13.571218
# 119   1.421524
# 124   0.209640
# 126   0.194862

# %%
# definitely one to remember... .isin() method

a_parties = ["Anti-Masonic", "American", "Anti-Monopoly", "American Independent"]
elections[elections["Party"].isin(a_parties)]
# Out:
#      Year           Candidate                 Party  Popular vote Result  \
# 6    1832        William Wirt          Anti-Masonic        100715   loss
# 22   1856    Millard Fillmore              American        873053   loss
# 38   1884     Benjamin Butler         Anti-Monopoly        134294   loss
# 115  1968      George Wallace  American Independent       9901118   loss
# 119  1972     John G. Schmitz  American Independent       1100868   loss
# 124  1976       Lester Maddox  American Independent        170274   loss
# 126  1976  Thomas J. Anderson              American        158271   loss
#
#              %
# 6     7.821583
# 22   21.554001
# 38    1.335838
# 115  13.571218
# 119   1.421524
# 124   0.209640
# 126   0.194862

# %%
elections[elections["Party"].str.startswith("A")]
# Out:
#      Year           Candidate                 Party  Popular vote Result  \
# 6    1832        William Wirt          Anti-Masonic        100715   loss
# 22   1856    Millard Fillmore              American        873053   loss
# 38   1884     Benjamin Butler         Anti-Monopoly        134294   loss
# 115  1968      George Wallace  American Independent       9901118   loss
# 119  1972     John G. Schmitz  American Independent       1100868   loss
# 124  1976       Lester Maddox  American Independent        170274   loss
# 126  1976  Thomas J. Anderson              American        158271   loss
#
#              %
# 6     7.821583
# 22   21.554001
# 38    1.335838
# 115  13.571218
# 119   1.421524
# 124   0.209640
# 126   0.194862

# %%
# query provides a SQL-like method to filter; note the parathesis required!!  it takes a str...
elections.query('Year >= 2000 and Result == "win"')
# Out:
#      Year       Candidate       Party  Popular vote Result          %
# 152  2000  George W. Bush  Republican      50456002    win  47.974666
# 157  2004  George W. Bush  Republican      62040610    win  50.771824
# 162  2008    Barack Obama  Democratic      69498516    win  53.023510
# 168  2012    Barack Obama  Democratic      65915795    win  51.258484
# 173  2016    Donald Trump  Republican      62984828    win  46.407862
# 178  2020    Joseph Biden  Democratic      81268924    win  51.311515

# %%
#query uses a different syntax for "in" and "not in"
parties = ["Republican", "Democratic"]
elections.query('Result == "win" and Party not in @parties')  #need the @ here because query takes a str input??
# Out:
#     Year               Candidate                  Party  Popular vote Result  \
# 1   1824       John Quincy Adams  Democratic-Republican        113142    win
# 11  1840  William Henry Harrison                   Whig       1275583    win
# 16  1848          Zachary Taylor                   Whig       1360235    win
# 27  1864         Abraham Lincoln         National Union       2211317    win
#
#             %
# 1   42.789878
# 11  53.051213
# 16  47.309296
# 27  54.951512

# %% [markdown]
# ## Built In Functions

# %%
winners = elections.query('Result == "win"')["%"]
winners.head(5)
# Out:
# 1     42.789878
# 2     56.203927
# 4     54.574789
# 8     52.272472
# 11    53.051213
# Name: %, dtype: float64

# %%
np.mean(winners)
# Out:
# 51.711492943

# %%
max(winners)
# Out:
# 61.34470329

# %%
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections.size  # this is #rows * #columns
# Out:
# 1092

# %%
elections.shape
# Out:
# (182, 6)

# %%
elections.describe()  #just does the numeric columns?  Not sure why
# Out:
#               Year  Popular vote           %
# count   182.000000  1.820000e+02  182.000000
# mean   1934.087912  1.235364e+07   27.470350
# std      57.048908  1.907715e+07   22.968034
# min    1824.000000  1.007150e+05    0.098088
# 25%    1889.000000  3.876395e+05    1.219996
# 50%    1936.000000  1.709375e+06   37.677893
# 75%    1988.000000  1.897775e+07   48.354977
# max    2020.000000  8.126892e+07   61.344703

# %%
elections.sample(5).iloc[:, 0:2] #gives a random sample

elections.sample(5).loc[:, ["Year", "Candidate"]]

elections[["Year", "Candidate"]]
# Out:
#      Year          Candidate
# 0    1824     Andrew Jackson
# 1    1824  John Quincy Adams
# 2    1828     Andrew Jackson
# 3    1828  John Quincy Adams
# 4    1832     Andrew Jackson
# ..    ...                ...
# 177  2016         Jill Stein
# 178  2020       Joseph Biden
# 179  2020       Donald Trump
# 180  2020       Jo Jorgensen
# 181  2020     Howard Hawkins
#
# [182 rows x 2 columns]

# %%
elections.query('Year == 2000').sample(4, replace = True).iloc[:, 0:2]
# Out:
#      Year     Candidate
# 153  2000  Harry Browne
# 153  2000  Harry Browne
# 151  2000       Al Gore
# 155  2000   Ralph Nader

# %%
## can't use chaining here???

elections.query("Year = 2000")
.sample(4, replace = True)
.iloc[:,0:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-c3b40c510c5f> in <module>
#       1 ## can't use chaining here???
#       2
# ----> 3 elections.query(("Year = 2000")
#       4 .sample(4, replace = True)
#       5 .iloc[:,0:2])
#
# AttributeError: 'str' object has no attribute 'sample'

# %%
elections["Candidate"].value_counts()  #like table and summary for factors?
# Out:
# Norman Thomas         5
# Ralph Nader           4
# Franklin Roosevelt    4
# Eugene V. Debs        4
# Andrew Jackson        3
#                      ..
# Silas C. Swallow      1
# Alton B. Parker       1
# John G. Woolley       1
# Joshua Levering       1
# Howard Hawkins        1
# Name: Candidate, Length: 132, dtype: int64

# %%
elections["Party"].unique()
# Out:
# array(['Democratic-Republican', 'Democratic', 'National Republican',
#        'Anti-Masonic', 'Whig', 'Free Soil', 'Republican', 'American',
#        'Constitutional Union', 'Southern Democratic',
#        'Northern Democratic', 'National Union', 'Liberal Republican',
#        'Greenback', 'Anti-Monopoly', 'Prohibition', 'Union Labor',
#        'Populist', 'National Democratic', 'Socialist', 'Progressive',
#        'Farmer–Labor', 'Communist', 'Union', 'Dixiecrat',
#        "States' Rights", 'American Independent', 'Independent',
#        'Libertarian', 'Citizens', 'New Alliance', 'Taxpayers',
#        'Natural Law', 'Green', 'Reform', 'Constitution'], dtype=object)

# %%
elections["Candidate"].sort_values()
# Out:
# 75           Aaron S. Watkins
# 27            Abraham Lincoln
# 23            Abraham Lincoln
# 108           Adlai Stevenson
# 105           Adlai Stevenson
#                 ...
# 19             Winfield Scott
# 37     Winfield Scott Hancock
# 74             Woodrow Wilson
# 70             Woodrow Wilson
# 16             Zachary Taylor
# Name: Candidate, Length: 182, dtype: object

# %%
elections.sort_values("%", ascending = False)
# Out:
#      Year           Candidate         Party  Popular vote Result          %
# 114  1964      Lyndon Johnson    Democratic      43127041    win  61.344703
# 91   1936  Franklin Roosevelt    Democratic      27752648    win  60.978107
# 120  1972       Richard Nixon    Republican      47168710    win  60.907806
# 79   1920      Warren Harding    Republican      16144093    win  60.574501
# 133  1984       Ronald Reagan    Republican      54455472    win  59.023326
# ..    ...                 ...           ...           ...    ...        ...
# 165  2008    Cynthia McKinney         Green        161797   loss   0.123442
# 148  1996        John Hagelin   Natural Law        113670   loss   0.118219
# 160  2004    Michael Peroutka  Constitution        143630   loss   0.117542
# 141  1992            Bo Gritz      Populist        106152   loss   0.101918
# 156  2004          David Cobb         Green        119859   loss   0.098088
#
# [182 rows x 6 columns]
